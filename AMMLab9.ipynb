# %%
! pip install sqlalchemy
! pip install PyMySQL

# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd
import getpass  # to get the password without showing the input
password = getpass.getpass() # insert your password below after executing this cell
# Out:
#  ········

# %%
connection_string = 'mysql+pymysql://root:' + password + '@localhost/sakila' # database_location/database_name
engine = create_engine(connection_string)

# %%
data = pd.read_sql_query('SELECT * FROM customer', engine)
data.head()
# Out:
#    customer_id  store_id first_name last_name
# 0            1         1       MARY     SMITH  \
# 1            2         1   PATRICIA   JOHNSON
# 2            3         1      LINDA  WILLIAMS
# 3            4         2    BARBARA     JONES
# 4            5         1  ELIZABETH     BROWN
#
#                                  email  address_id  active
# 0        MARY.SMITH@sakilacustomer.org           5       1  \
# 1  PATRICIA.JOHNSON@sakilacustomer.org           6       1
# 2    LINDA.WILLIAMS@sakilacustomer.org           7       1
# 3     BARBARA.JONES@sakilacustomer.org           8       1
# 4   ELIZABETH.BROWN@sakilacustomer.org           9       1
#
#           create_date         last_update
# 0 2006-02-14 22:04:36 2006-02-15 04:57:20
# 1 2006-02-14 22:04:36 2006-02-15 04:57:20
# 2 2006-02-14 22:04:36 2006-02-15 04:57:20
# 3 2006-02-14 22:04:36 2006-02-15 04:57:20
# 4 2006-02-14 22:04:36 2006-02-15 04:57:20

# %%
result = engine.execute('SELECT * FROM customer')
df = pd.DataFrame(result)
df
# Out:
#      customer_id  store_id first_name  last_name
# 0              1         1       MARY      SMITH  \
# 1              2         1   PATRICIA    JOHNSON
# 2              3         1      LINDA   WILLIAMS
# 3              4         2    BARBARA      JONES
# 4              5         1  ELIZABETH      BROWN
# ..           ...       ...        ...        ...
# 594          595         1   TERRENCE  GUNDERSON
# 595          596         1    ENRIQUE   FORSYTHE
# 596          597         1    FREDDIE     DUGGAN
# 597          598         1       WADE   DELVALLE
# 598          599         2     AUSTIN    CINTRON
#
#                                      email  address_id  active
# 0            MARY.SMITH@sakilacustomer.org           5       1  \
# 1      PATRICIA.JOHNSON@sakilacustomer.org           6       1
# 2        LINDA.WILLIAMS@sakilacustomer.org           7       1
# 3         BARBARA.JONES@sakilacustomer.org           8       1
# ...

# %%
def compare_rentals(may_df, june_df, customer_id):
 
    may_rentals = may_df[may_df['customer_id'] == customer_id]
    june_rentals = june_df[june_df['customer_id'] == customer_id]
    

    may_rental_count = len(may_rentals)
    june_rental_count = len(june_rentals)
    
  
    if june_rental_count > may_rental_count:
        return f"Customer {customer_id} borrowed more films in June compared to May."
    elif june_rental_count < may_rental_count:
        return f"Customer {customer_id} borrowed fewer films in June compared to May."
    else:
        return f"Customer {customer_id} borrowed the same number of films in May and June."

# %%
customer_id = 1

result = compare_rentals( may_rental_count, june_rental_coun, customer_id)
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 customer_id = 1
# ----> 3 result = compare_rentals( may_rental_count, june_rental_coun, customer_id)
#       4 print(result)
#
# NameError: name 'may_rental_count' is not defined

# %%
# I will check again the class, i don't really know what am I doing here :)
